# %%
import sys
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import glob
from mirror_symmetry import * # class and helper function
# %matplotlib inline

# %%
import os

dir_path = 'problems_png'

if not os.path.exists(dir_path):
    os.makedirs(dir_path)
    print(f"Directory '{dir_path}' created.")
else:
    print(f"Directory '{dir_path}' already exists.")
# Out:
# Directory 'problems_png' already exists.

# %%
import cairosvg

input_svg = 'problems/occlusion2.svg'

output_png = 'problems_png/occlusion2.png'

cairosvg.svg2png(url=input_svg, write_to=output_png)

# %%
detecting_mirrorLine(output_png, 'isolated mirror line', True)
